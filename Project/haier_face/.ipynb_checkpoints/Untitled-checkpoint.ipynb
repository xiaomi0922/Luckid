# %%
import os 
import shutil

# %%
for i, j, k in os.walk("static\\masked_whn"):
    base_path = "D:\\Smart\\face_recognition\\"
    if i == "static\masked_whn":
        continue
    name = i.split('_')[-2]
    path = base_path + i + '\\unmasked.jpg'
    new_path = base_path + i + "\\" + name + ".jpg"
    move_path = "D:\\Smart\\face_recognition\\static\\data\\" + name + ".jpg"
    shutil.move(new_path, move_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-57896e9bbc92> in <module>
#       7     new_path = base_path + i + "\\" + name + ".jpg"
#       8     move_path = "D:\\Smart\\face_recognition\\static\\data\\" + name + ".jpg"
# ----> 9     shutil.move(new_path, move_path)
#
# NameError: name 'shutil' is not defined
